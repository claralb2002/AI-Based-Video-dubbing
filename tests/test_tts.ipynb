# %%
import sys
import os

# Get the absolute path to the project root (parent directory of the current folder)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the project root to sys.path
sys.path.append(project_root)

# %% [markdown]
# ---
#
# ## MMS

# %%
from models.text_to_speech import MMS_speaker

tts_eng = MMS_speaker()
# Out:
# Loading MMS model: facebook/mms-tts-eng
# MMS speaker model loaded!

# %%
tts_eng.speak("WAS NOT THE ONLY VILLAGE TO BE SEEN FROM BLUE MOUNTAIN THERE WAS ANOTHER WHICH FARMER GREEN SELDOM VISITED ")

# %% [markdown]
# ---
#
# ## SpeechT5 danish tuned

# %%
from models.text_to_speech import DanishSpeechT5

tts_dk = DanishSpeechT5()
# Out:
# Loading SpeechT5 Danish model: JackismyShephard/speecht5_tts-finetuned-nst-da
# Danish SpeechT5 model loaded!

# %%
tts_dk.speak("Jeg har kendt mange fisk i mit liv, men jeg har kun elsket to. Den første var mere som en lidenskabelig affære.")

# %%
tts_dk.speak("Jeg har kendt mange fisk i mit liv, men jeg har kun elsket to. Den første var mere som en lidenskabelig affære. Det var en smuk fisk med en smagfuld konsistens og kødfuldhed, en bestseller på menuen. Hvilken fisk! Endnu bedre var det, at den var opdrættet efter de højeste standarder for bæredygtighed, så man kunne have god samvittighed ved at sælge den.")
