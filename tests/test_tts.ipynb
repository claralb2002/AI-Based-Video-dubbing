# %%
import sys
import os

# Get the absolute path to the project root (parent directory of the current folder)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the project root to sys.path
sys.path.append(project_root)

# %% [markdown]
# ### SpeechT5

# %%
from models.text_to_speech import SpeechT5
SpeechT5 = SpeechT5()

# %%
chunks = [
    "liquid cool",
    "bird for experimental",
    "Data collection methods are appropriate",
]

for chunk in chunks:
    SpeechT5.speak(chunk)

# %% [markdown]
# ---
#
# ## MMS

# %%
from models.text_to_speech import MMS_speaker

tts_eng = MMS_speaker()
# Out:
# Loading MMS model: facebook/mms-tts-eng
# MMS speaker model loaded!

# %%
chunks = [
    "liquid is cool",
    "bird for experimental",
    "Data collection methods are appropriate",
]

for chunk in chunks:
    tts_eng.speak(chunk, speed=1.0)

# %% [markdown]
# ---
#
# ## SpeechT5 danish tuned

# %%
from models.text_to_speech import DanishSpeechT5

tts_dk = DanishSpeechT5()
# Out:
# Loading SpeechT5 Danish model: JackismyShephard/speecht5_tts-finetuned-nst-da
# Danish SpeechT5 model loaded!

# %%
chunks = [
    "100 mænd og 900 kvinder,",
    # "for at etablere fakta og nå nye konklusioner.",
    # "dekadence optræder i samfundet.",
]

for chunk in chunks:
    tts_dk.speak(chunk, speed=1.0)
