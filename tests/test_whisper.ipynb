# %% [markdown]
# ### Importing model

# %%
from models.whisper_transcriber import WhisperTranscriber

# Load model once before testing 
# choose model size from "tiny", "base", "small", "medium", "large"
transcriber = WhisperTranscriber(model_size="medium")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from models.whisper_transcriber import WhisperTranscriber
#       3 # Load model once before testing
#       4 # choose model size from "tiny", "base", "small", "medium", "large"
#       5 transcriber = WhisperTranscriber(model_size="medium")
#
# ModuleNotFoundError: No module named 'models'

# %% [markdown]
# ### Load data

# %%
data_path = "data/Test_demo.m4a"

# %%
from utils.audio_processing import preprocess_audio

preprocess_audio(data_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Now import the function
# ----> 2 from utils.audio_processing import preprocess_audio
#       4 preprocess_audio(data_path)
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# ### Testing different chunk sizes

# %%
# Test with a short chunk size
transcriptions = transcriber.transcribe_audio_in_chunks(data_path, chunk_duration_ms=2000)
print("Short chunk size test:", " ".join(transcriptions))

# %%
# Test with a large chunk size
transcriptions = transcriber.transcribe_audio_in_chunks(data_path, chunk_duration_ms=10000)
print("Larger chunk size test:", " ".join(transcriptions))
